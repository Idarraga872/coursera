# %%
#!pip install requests

# %%
import requests

# %%
url = 'https://www.pagina12.com.ar/'

# %%
p12 = requests.get(url) #Hace el Get de la página web

# %%
p12.status_code #Muestra el status de la respuesta
# Out:
# 200

# %%
print(p12.text)
# Out:
# <!DOCTYPE html><html class="no-js " lang="es"><head><meta charset="utf-8"><title>Página | 12: La otra mirada sobre Argentina y el mundo</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><link rel="canonical" href="https://www.pagina12.com.ar"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}</script><meta property="description" name="description" content="Información sobre Argentina y el mundo. Noticias en fotos y videos de los principales hechos y acontecimientos del país. Análisis, opinión y entrevistas."><meta property="fb:pages"
# ...

# %%
p12.content
# Out:
# b'<!DOCTYPE html><html class="no-js " lang="es"><head><meta charset="utf-8"><title>P\xc3\xa1gina | 12: La otra mirada sobre Argentina y el mundo</title><meta name="google-site-verification" content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg"><link rel="canonical" href="https://www.pagina12.com.ar"><script type="application/ld+json">{"@context": "http://schema.org","@type": "Organization","name": "P\xc3\xa1gina12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}</script><meta property="description" name="description" content="Informaci\xc3\xb3n sobre Argentina y el mundo. Noticias en fotos y videos de los principales hechos y acontecimientos del pa\xc3\xads. An\xc3\xa1lisis, opini\xc3\xb
# ...

# %%
p12.headers
# Out:
# {'Date': 'Sat, 11 Feb 2023 17:18:00 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'vary': 'Accept-Encoding', 'x-dns-prefetch-control': 'off', 'strict-transport-security': 'max-age=15724800; includeSubDomains', 'x-download-options': 'noopen', 'x-content-type-options': 'nosniff', 'x-xss-protection': '1; mode=block', 'x-etag': 'W/"6efcf-QAMDQl89pNvk3Y3hrBYkdoKFkZM"', 'x-backend': 'frontend', 'x-type': 'Dynamic URI', 'x-backend-ttl': '120.000', 'age': '92', 'grace': '86400.000 none', 'ttl': '27.649', 'x-instance': 'cache-front-prod-varnish-86654b9966-p5shb', 'x-restarts': '0', 'x-cache': 'hit cached', 'CF-Cache-Status': 'DYNAMIC', 'Server-Timing': 'cf-q-config;dur=7.0000023697503e-06', 'Server': 'cloudflare', 'CF-RAY': '797ebdc60f960992-MIA', 'Content-Encoding': 'br'}

# %%
p12.request.headers #Headers del servidor
# Out:
# {'User-Agent': 'python-requests/2.27.1', 'Accept-Encoding': 'gzip, deflate, br', 'Accept': '*/*', 'Connection': 'keep-alive'}

# %%
p12.request.method
# Out:
# 'GET'

# %%
p12.request.url
# Out:
# 'https://www.pagina12.com.ar/'

# %%
#!pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
s = BeautifulSoup(p12.text, 'lxml') #Parcear el texto en pedazos más pequeños

# %%
type(s)
# Out:
# bs4.BeautifulSoup

# %%
print(s.prettify()) #Estructura de la página más ordenado
# Out:
# <!DOCTYPE html>
# <html class="no-js" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Página | 12: La otra mirada sobre Argentina y el mundo
#   </title>
#   <meta content="x6zSdT0DBcKDmridH4LpEVrCmxcOunR2dgBQVmuL6fg" name="google-site-verification"/>
#   <link href="https://www.pagina12.com.ar" rel="canonical"/>
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}
#   </script>
# ...

# %%
s.find('ul') #Encuentra un elemento específico dentro del código de la página
# Out:
# <ul class="horizontal-list main-supplements hide-on-mobile"><li><span class="today">Hoy:</span></li><li class=""><a href="https://www.pagina12.com.ar/suplementos/verano12">Verano12</a></li></ul>

# %%
s.find('ul', attrs={'class':'horizontal-list main-sections hide-on-dropdown'}).find_all('li') #Encuentra un elemento de forma más específica
# Out:
# [<li class="p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a></li>,
#  <li class="p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/economia">Economía</a></li>,
#  <li class="p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a></li>,
#  <li class="no-separator-on-1040 p12-separator--right--blue"><a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Espectáculos</a></li>,
#  <li class="hide-on-1040 p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a></li>,
#  <li class="hide-on-1040 p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/ciencia">Ciencia</a></li>,
#  <li class="hide-on-1040"><a href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a></li>]

# %%
secciones = s.find('ul', attrs = {'class': 'horizontal-list main-sections hide-on-dropdown'}).find_all('li') #Encuentra todos los que sean li dentro del texto buscado
secciones
# Out:
# [<li class="p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/el-pais">El país</a></li>,
#  <li class="p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/economia">Economía</a></li>,
#  <li class="p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/sociedad">Sociedad</a></li>,
#  <li class="no-separator-on-1040 p12-separator--right--blue"><a href="https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos">Espectáculos</a></li>,
#  <li class="hide-on-1040 p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/deportes">Deportes</a></li>,
#  <li class="hide-on-1040 p12-separator--right--blue"><a href="https://www.pagina12.com.ar/secciones/ciencia">Ciencia</a></li>,
#  <li class="hide-on-1040"><a href="https://www.pagina12.com.ar/secciones/el-mundo">El mundo</a></li>]

# %%
seccion = secciones[0]

# %%
seccion.a.get('href') #Obtenemos en forma de string el atributo href
# Out:
# 'https://www.pagina12.com.ar/secciones/el-pais'

# %%
seccion.a.get_text() #Texto de la seccion
# Out:
# 'El país'

# %%
links_secciones = [seccion.a.get('href') for seccion in secciones] #Lista con los links de las secciones

# %%
links_secciones
# Out:
# ['https://www.pagina12.com.ar/secciones/el-pais',
#  'https://www.pagina12.com.ar/secciones/economia',
#  'https://www.pagina12.com.ar/secciones/sociedad',
#  'https://www.pagina12.com.ar/suplementos/cultura-y-espectaculos',
#  'https://www.pagina12.com.ar/secciones/deportes',
#  'https://www.pagina12.com.ar/secciones/ciencia',
#  'https://www.pagina12.com.ar/secciones/el-mundo']

# %%
sec = requests.get(links_secciones[0])

# %%
sec.status_code
# Out:
# 200

# %%
s_seccion = BeautifulSoup(sec.text, 'lxml')

# %%
print(s_seccion.prettify())
# Out:
# <!DOCTYPE html>
# <html amp="" lang="es">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    El país | Página12
#   </title>
#   <!-- DUST PATH: /usr/src/app/src/widgets/fc_jsonLD.dust/ -->
#   <script type="application/ld+json">
#    {"@context": "http://schema.org","@type": "Organization","name": "Página12","url": "https://www.pagina12.com.ar","logo": {"@type": "ImageObject","url": "https://www.pagina12.com.ar/assets/media/logo_default_p12.png","width": "600","height": "60"},"sameAs":["https://twitter.com/pagina12","https://www.youtube.com/channel/UCJNDedOnljCssaiRZqg8-Dg","https://www.instagram.com/pagina12/","https://www.facebook.com/Pagina12ok/"]}
#   </script>
#   <script type="application/ld+json">
# ...

# %%
featured_article = s_seccion.find('div', attrs = {'class': 'column medium-7'})#Nuevo elemento de la nueva seccion

# %%
featured_article

# %%
featured_article.a.get('href')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [58], in <cell line: 1>()
# ----> 1 featured_article.a.get('href')
#
# AttributeError: 'NoneType' object has no attribute 'a'

# %%
article_list = s_seccion.find('div', attrs = {'class': 'articles-list'}) #Obtenemos los otros articulos de la seccion

# %%
article_list
# Out:
# <div class="articles-list is-grid-col2 grid-mobile-row"><!-- DUST PATH: /usr/src/app/src/templates/partials/amp/lists/articles_list_item.dust/ --><!-- DUST PATH: /usr/src/app/src/templates/partials/amp/articles/featured_article.dust/ --><article class="article-item article-item--featured"><!-- Image --><div class="article-item__header deco-bar-here-bottom is-mobile-left"><a href="/523146-atentado-a-cfk-la-justicia-volvio-a-rechazar-el-arresto-domi"><!-- DUST PATH: /usr/src/app/node_modules/frontend-core/views/widgets/fc_displayImg_amp.dust/ --><amp-img alt="Es el segundo intento realizado por la defensa de Carrizo para que obtenga la prisión domiciliaria. (Fuente: Télam)" class="" height="313" layout="responsive" src="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2023-02/696795-11-02-2023-la-jueza-federal-maria-eugenia.jpg?itok=9Yh56pPX" srcset="https://images.pagina12.com.ar/styles/focal_3_2_470x313/public/2023-02/696795-11-02-2023-la-jueza-federal-maria-eugenia.jpg
# ...

# %% [markdown]
# # Clase 2: Manejo de errores

# %%
r = requests.get(url)

# %%
if r.status_code == 200:
    # Procesar respuesta
else: 
    # Informar el error
# Out:
#   Input In [66]
#     else:
#     ^
# IndentationError: expected an indented block

# %%
url_mala = url.replace('2', '3')
url_mala
# Out:
# 'https://www.pagina13.com.ar/'

# %%
try: #Se hace el request y si sale un error se pasa al codigo del except
    requests.get(url_mala)
except Exception as e: 
    print('error en la request')
    print(e)
    print('\n')
# Out:
# error en la request
# HTTPSConnectionPool(host='www.pagina13.com.ar', port=443): Max retries exceeded with url: / (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x00000160E200D6A0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))

# %%
try: #Intenta la linea y si falla continua el proceso
    featured_article.b.get('href')
except:
    pass
print('Hola')
# Out:
# Hola

# %%
def obtener_notas(soup):
    '''
    Función que recibe un objeto de BeautifulSoup de una página de una sección
    y devuelve una lista de URLs a las notas de esa sección
    '''
    lista_notas = []
    
    # Obtengo el artículo promocionado
    featured_article = soup.find('div', attrs={'class':'featured-article__container'})
    if featured_article:
        lista_notas.append(featured_article.a.get('href'))
    
    # Obtengo el listado de artículos
    article_list = soup.find('div', attrs={'class':'articles-list'})
    for article in article_list.find_all('article'):
        ref = article.find('div', attrs = {'class': 'article-item__header'})
        if ref.a:
            lista_notas.append(ref.a.get('href'))
    
    return lista_notas

# %%
lista_notas = obtener_notas(s_seccion)
lista_notas
# Out:
# ['/523146-atentado-a-cfk-la-justicia-volvio-a-rechazar-el-arresto-domi',
#  '/523056-juicio-a-la-conspiracion']

# %%
url_nota = lista_notas[0]

# %%
url_nota
# Out:
# '/523146-atentado-a-cfk-la-justicia-volvio-a-rechazar-el-arresto-domi'
